# %%
cd /u/nijaid/work/OB150211/a_2017_08_28/a_ob150211_2017_08_28_a4_m18_w4_MC100
# Out:
# /u/nijaid/work/OB150211/a_2017_08_28/a_ob150211_2017_08_28_a4_m18_w4_MC100

# %%
run ~/microlens/align_plots/code/align_plot.py

# %%
epochs_0211 = ['15may05','15jun07','15jun28','15jul23','16may03','16jul14','16aug02','17jun05','17jun08','17jul19']

# %%
for ep in range(len(epochs_0211)):
    epoch_quiver('ob150211', epochs_0211[ep], ep)
# Out:
# /u/nijaid/work/OB150211/a_2017_08_28/a_ob150211_2017_08_28_a4_m18_w4_MC100
# *******************
# Trimmed 38 stars with too-large residuals (>10 pix)
# /u/nijaid/work/OB150211/a_2017_08_28/a_ob150211_2017_08_28_a4_m18_w4_MC100
# *******************
# Trimmed 38 stars with too-large residuals (>10 pix)
# /u/nijaid/work/OB150211/a_2017_08_28/a_ob150211_2017_08_28_a4_m18_w4_MC100
# *******************
# Trimmed 38 stars with too-large residuals (>10 pix)
# /u/nijaid/work/OB150211/a_2017_08_28/a_ob150211_2017_08_28_a4_m18_w4_MC100
# *******************
# Trimmed 38 stars with too-large residuals (>10 pix)
# /u/nijaid/work/OB150211/a_2017_08_28/a_ob150211_2017_08_28_a4_m18_w4_MC100
# *******************
# Trimmed 38 stars with too-large residuals (>10 pix)
# WARNING: VerifyWarning: Invalid 'BLANK' keyword in header.  The 'BLANK' keyword is only applicable to integer data, and will be ignored in this HDU. [astropy.io.fits.hdu.image]
# ...
