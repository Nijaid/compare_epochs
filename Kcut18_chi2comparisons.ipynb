# %%
run microlens/align_plots/code/align_plot.py

# %%
compare_orders('ob140613', '2017_07_28')
# Out:
# Weight = 1
# ('Skipping Ref Epoch', 2)
# /anaconda/envs/iraf27/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2889: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda/envs/iraf27/lib/python2.7/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /u/jlu/code/python/jlu_python/jlu/microlens/residuals.py:612: RuntimeWarning: Mean of empty slice.
#   xresid_err_p_used[ee] = xe_p[ee, idx][used].mean() / N_stars_used[ee]**0.5
# /u/jlu/code/python/jlu_python/jlu/microlens/residuals.py:613: RuntimeWarning: Mean of empty slice.
#   yresid_err_p_used[ee] = ye_p[ee, idx][used].mean() / N_stars_used[ee]**0.5
# /u/jlu/code/python/jlu_python/jlu/microlens/residuals.py:618: RuntimeWarning: Mean of empty slice.
#   xresid_err_a_used[ee] = xe_a[ee, idx][used].mean() / N_stars_used[ee]**0.5
# ...

# %%
compare_orders('ob150029', '2017_07_28')
# Out:
# Weight = 1
# ('Skipping Ref Epoch', 2)
# ('Skipping Ref Epoch', 2)
# Epoch: 2015.432
# N_stars =  28  N_par =   3  N_dof =  25  Chi^2 X = 252.1  Chi^2 Y = 333.1  Chi^2 Tot = 585.1
# N_stars =  28  N_par =   6  N_dof =  22  Chi^2 X = 2444.3  Chi^2 Y = 1273.4  Chi^2 Tot = 3717.7
# N_stars =  28  N_par =  10  N_dof =  18  Chi^2 X = 2269.9  Chi^2 Y = 4394.0  Chi^2 Tot = 6663.9
# M = 4: M-1 --> M     Fa = -6.18 pa =  1.0000    Fx = -6.58 px =  1.0000   Fy = -5.42 py =  1.0000
# M = 5: M-1 --> M     Fa = -1.99 pa =  1.0000    Fx =  0.35 px =  0.8435   Fy = -3.20 py =  1.0000
#
# Epoch: 2015.557
# N_stars =  28  N_par =   3  N_dof =  25  Chi^2 X = 203.5  Chi^2 Y = 285.2  Chi^2 Tot = 488.7
# N_stars =  28  N_par =   6  N_dof =  22  Chi^2 X = 1795.1  Chi^2 Y = 535.8  Chi^2 Tot = 2330.9
# N_stars =  28  N_par =  10  N_dof =  18  Chi^2 X = 2275.8  Chi^2 Y = 377.4  Chi^2 Tot = 2653.2
# M = 4: M-1 --> M     Fa = -5.80 pa =  1.0000    Fx = -6.50 px =  1.0000   Fy = -3.43 py =  1.0000
# ...

# %%
compare_orders('ob150211', '2017_07_28')
# Out:
# Weight = 1
# ('Skipping Ref Epoch', 4)
# ('Skipping Ref Epoch', 4)
# Epoch: 2015.341
# N_stars =  40  N_par =   3  N_dof =  37  Chi^2 X = 904.0  Chi^2 Y = 343.8  Chi^2 Tot = 1247.7
# N_stars =  40  N_par =   6  N_dof =  34  Chi^2 X = 1330.9  Chi^2 Y = 565.7  Chi^2 Tot = 1896.6
# N_stars =  40  N_par =  10  N_dof =  30  Chi^2 X = 1176.6  Chi^2 Y = 573.1  Chi^2 Tot = 1749.7
# M = 4: M-1 --> M     Fa = -3.88 pa =  1.0000    Fx = -3.64 px =  1.0000   Fy = -4.45 py =  1.0000
# M = 5: M-1 --> M     Fa =  0.63 pa =  0.7496    Fx =  0.98 px =  0.4314   Fy = -0.10 py =  1.0000
#
# Epoch: 2015.431
# N_stars =  40  N_par =   3  N_dof =  37  Chi^2 X = 162.2  Chi^2 Y = 319.7  Chi^2 Tot = 481.8
# N_stars =  40  N_par =   6  N_dof =  34  Chi^2 X = 1099.8  Chi^2 Y = 534.9  Chi^2 Tot = 1634.6
# N_stars =  40  N_par =  10  N_dof =  30  Chi^2 X = 805.5  Chi^2 Y = 584.7  Chi^2 Tot = 1390.2
# M = 4: M-1 --> M     Fa = -7.99 pa =  1.0000    Fx = -9.66 px =  1.0000   Fy = -4.56 py =  1.0000
# ...
