# %%
cd /u/nijaid/work/OB150029/a_2017_08_28/a_ob150029_2017_08_28_a4_m18_w3_MC100
# Out:
# /u/nijaid/work/OB150029/a_2017_08_28/a_ob150029_2017_08_28_a4_m18_w3_MC100

# %%
run ~/microlens/align_plots/code/align_plot.py

# %%
epochs_0029 = ['15jun07','15jul23','16may24','16jul14','17may21','17jul14','17jul19']

# %%
for ep in range(len(epochs_0029)):
    epoch_quiver('ob150029', epochs_0029[ep], ep)
# Out:
# /u/nijaid/work/OB150029/a_2017_08_28/a_ob150029_2017_08_28_a4_m18_w3_MC100
# *******************
# Trimmed 102 stars with too-large residuals (>10 pix)
# /u/nijaid/work/OB150029/a_2017_08_28/a_ob150029_2017_08_28_a4_m18_w3_MC100
# *******************
# Trimmed 102 stars with too-large residuals (>10 pix)
# /u/nijaid/work/OB150029/a_2017_08_28/a_ob150029_2017_08_28_a4_m18_w3_MC100
# *******************
# Trimmed 102 stars with too-large residuals (>10 pix)
# WARNING: VerifyWarning: Invalid 'BLANK' keyword in header.  The 'BLANK' keyword is only applicable to integer data, and will be ignored in this HDU. [astropy.io.fits.hdu.image]
# /u/nijaid/work/OB150029/a_2017_08_28/a_ob150029_2017_08_28_a4_m18_w3_MC100
# *******************
# Trimmed 102 stars with too-large residuals (>10 pix)
# /u/nijaid/work/OB150029/a_2017_08_28/a_ob150029_2017_08_28_a4_m18_w3_MC100
# *******************
# Trimmed 102 stars with too-large residuals (>10 pix)
# ...
