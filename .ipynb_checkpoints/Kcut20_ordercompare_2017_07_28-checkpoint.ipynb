# %%
run ~/microlens/align_plots/code/align_plot.py

# %%
compare_orders('ob140613', '2017_07_28', Kcut=20)
# Out:
# ** Weight = 1 **
# ('Skipping Ref Epoch', 2)
# /anaconda/envs/iraf27/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2889: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda/envs/iraf27/lib/python2.7/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /u/jlu/code/python/jlu_python/jlu/microlens/residuals.py:612: RuntimeWarning: Mean of empty slice.
#   xresid_err_p_used[ee] = xe_p[ee, idx][used].mean() / N_stars_used[ee]**0.5
# /u/jlu/code/python/jlu_python/jlu/microlens/residuals.py:613: RuntimeWarning: Mean of empty slice.
#   yresid_err_p_used[ee] = ye_p[ee, idx][used].mean() / N_stars_used[ee]**0.5
# /u/jlu/code/python/jlu_python/jlu/microlens/residuals.py:618: RuntimeWarning: Mean of empty slice.
#   xresid_err_a_used[ee] = xe_a[ee, idx][used].mean() / N_stars_used[ee]**0.5
# ...

# %%
compare_orders('ob150029', '2017_07_28', Kcut=20)
# Out:
# ** Weight = 1 **
# ('Skipping Ref Epoch', 2)
# ('Skipping Ref Epoch', 2)
# Epoch: 2015.432
# N_stars = 107  N_par =   3  N_dof = 104  Chi^2 X = 309.2  Chi^2 Y = 559.8  Chi^2 Tot = 869.0
# N_stars = 107  N_par =   6  N_dof = 101  Chi^2 X = 415.1  Chi^2 Y = 3595.5  Chi^2 Tot = 4010.6
# N_stars = 107  N_par =  10  N_dof =  97  Chi^2 X = 2909.2  Chi^2 Y = 2889.8  Chi^2 Tot = 5799.0
# M = 4: M-1 --> M     Fa = -26.37 pa =  1.0000    Fx = -8.59 px =  1.0000   Fy = -28.43 py =  1.0000
# M = 5: M-1 --> M     Fa = -7.48 pa =  1.0000    Fx = -20.79 px =  1.0000   Fy =  5.92 py =  0.0003
#
# Epoch: 2015.557
# N_stars = 105  N_par =   3  N_dof = 102  Chi^2 X = 1717.4  Chi^2 Y = 541.9  Chi^2 Tot = 2259.3
# N_stars = 105  N_par =   6  N_dof =  99  Chi^2 X = 3647.9  Chi^2 Y = 1202.6  Chi^2 Tot = 4850.5
# N_stars = 105  N_par =  10  N_dof =  95  Chi^2 X = 7020.0  Chi^2 Y = 1757.5  Chi^2 Tot = 8777.5
# ...

# %%
compare_orders('ob150211', '2017_07_28', Kcut=20)
# Out:
# ** Weight = 1 **
# ('Skipping Ref Epoch', 4)
# ('Skipping Ref Epoch', 4)
# Epoch: 2015.341
# N_stars =  40  N_par =   3  N_dof =  37  Chi^2 X = 886.4  Chi^2 Y = 343.1  Chi^2 Tot = 1229.5
# N_stars =  40  N_par =   6  N_dof =  34  Chi^2 X = 1374.2  Chi^2 Y = 592.2  Chi^2 Tot = 1966.4
# N_stars =  40  N_par =  10  N_dof =  30  Chi^2 X = 1335.2  Chi^2 Y = 691.8  Chi^2 Tot = 2027.0
# M = 4: M-1 --> M     Fa = -4.25 pa =  1.0000    Fx = -4.02 px =  1.0000   Fy = -4.77 py =  1.0000
# M = 5: M-1 --> M     Fa = -0.22 pa =  1.0000    Fx =  0.22 px =  0.9258   Fy = -1.08 py =  1.0000
#
# Epoch: 2015.431
# N_stars =  40  N_par =   3  N_dof =  37  Chi^2 X = 174.9  Chi^2 Y = 309.6  Chi^2 Tot = 484.5
# N_stars =  40  N_par =   6  N_dof =  34  Chi^2 X = 1156.2  Chi^2 Y = 549.9  Chi^2 Tot = 1706.1
# N_stars =  40  N_par =  10  N_dof =  30  Chi^2 X = 984.4  Chi^2 Y = 612.3  Chi^2 Tot = 1596.7
# M = 4: M-1 --> M     Fa = -8.12 pa =  1.0000    Fx = -9.62 px =  1.0000   Fy = -4.95 py =  1.0000
# ...
