# %%
cd /u/nijaid/work/OB140613/a_2017_08_28/a_ob140613_2017_08_28_a4_m18_w4_MC100
# Out:
# /u/nijaid/work/OB140613/a_2017_08_28/a_ob140613_2017_08_28_a4_m18_w4_MC100

# %%
run ~/microlens/align_plots/code/align_plot.py

# %%
epochs_0613 = ['15jun28','15jun07','16apr17','16may24','16aug02', '17jun05', '17jul14']

# %%
for ep in range(len(epochs_0613)):
    epoch_quiver('ob140613', epochs_0613[ep], ep)
# Out:
# /u/nijaid/work/OB140613/a_2017_08_28/a_ob140613_2017_08_28_a4_m18_w4_MC100
# *******************
# Trimmed 129 stars with too-large residuals (>10 pix)
# /u/nijaid/work/OB140613/a_2017_08_28/a_ob140613_2017_08_28_a4_m18_w4_MC100
# *******************
# Trimmed 129 stars with too-large residuals (>10 pix)
# /u/nijaid/work/OB140613/a_2017_08_28/a_ob140613_2017_08_28_a4_m18_w4_MC100
# *******************
# Trimmed 129 stars with too-large residuals (>10 pix)
# /u/nijaid/work/OB140613/a_2017_08_28/a_ob140613_2017_08_28_a4_m18_w4_MC100
# *******************
# WARNING: VerifyWarning: Invalid 'BLANK' keyword in header.  The 'BLANK' keyword is only applicable to integer data, and will be ignored in this HDU. [astropy.io.fits.hdu.image]
# Trimmed 129 stars with too-large residuals (>10 pix)
# /u/nijaid/work/OB140613/a_2017_08_28/a_ob140613_2017_08_28_a4_m18_w4_MC100
# *******************
# Trimmed 129 stars with too-large residuals (>10 pix)
# ...
