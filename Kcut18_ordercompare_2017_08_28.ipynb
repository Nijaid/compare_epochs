# %%
run ~/microlens/align_plots/code/align_plot.py

# %%
compare_orders('ob140613', '2017_08_28')
# Out:
# ** Weight = 1 **
# Skipping Ref Epoch 2016.395
# Skipping Ref Epoch 2016.395
# Epoch: 2015.431
# N_stars =  50  N_par =   3  N_dof =  47  Chi^2 X = 6104.4  Chi^2 Y = 13378.5  Chi^2 Tot = 19482.9
# N_stars =  50  N_par =   6  N_dof =  44  Chi^2 X = 8142.3  Chi^2 Y = 5146.5  Chi^2 Tot = 13288.7
# N_stars =  50  N_par =  10  N_dof =  40  Chi^2 X = 14166.1  Chi^2 Y = 1941.5  Chi^2 Tot = 16107.6
# M = 4: M-1 --> M     Fa =  6.84 pa =  0.0000    Fx = -3.67 px =  1.0000   Fy = 23.46 py =  0.0000
# M = 5: M-1 --> M     Fa = -1.75 pa =  1.0000    Fx = -4.25 px =  1.0000   Fy = 16.51 py =  0.0000
#
# Epoch: 2015.491
# N_stars =  54  N_par =   3  N_dof =  51  Chi^2 X = 218.5  Chi^2 Y = 162.9  Chi^2 Tot = 381.4
# N_stars =  54  N_par =   6  N_dof =  48  Chi^2 X = 242.8  Chi^2 Y = 201.2  Chi^2 Tot = 444.0
# N_stars =  54  N_par =  10  N_dof =  44  Chi^2 X = 267.4  Chi^2 Y = 160.3  Chi^2 Tot = 427.7
# ...

# %%
compare_orders('ob150029', '2017_08_28')
# Out:
# ** Weight = 1 **
# Skipping Ref Epoch 2016.395
# Skipping Ref Epoch 2016.395
# Epoch: 2015.432
# N_stars =  28  N_par =   3  N_dof =  25  Chi^2 X = 816.4  Chi^2 Y = 172.8  Chi^2 Tot = 989.3
# N_stars =  28  N_par =   6  N_dof =  22  Chi^2 X = 1337.5  Chi^2 Y = 224.2  Chi^2 Tot = 1561.6
# N_stars =  28  N_par =  10  N_dof =  18  Chi^2 X = 1329.2  Chi^2 Y = 440.9  Chi^2 Tot = 1770.0
# M = 4: M-1 --> M     Fa = -2.69 pa =  1.0000    Fx = -2.86 px =  1.0000   Fy = -1.68 py =  1.0000
# M = 5: M-1 --> M     Fa = -0.53 pa =  1.0000    Fx =  0.03 px =  0.9983   Fy = -2.21 py =  1.0000
#
# Epoch: 2015.557
# N_stars =  28  N_par =   3  N_dof =  25  Chi^2 X = 439.6  Chi^2 Y = 306.1  Chi^2 Tot = 745.7
# N_stars =  28  N_par =   6  N_dof =  22  Chi^2 X = 1842.0  Chi^2 Y = 527.2  Chi^2 Tot = 2369.2
# N_stars =  28  N_par =  10  N_dof =  18  Chi^2 X = 2337.9  Chi^2 Y = 509.0  Chi^2 Tot = 2846.9
# M = 4: M-1 --> M     Fa = -5.03 pa =  1.0000    Fx = -5.58 px =  1.0000   Fy = -3.08 py =  1.0000
# ...

# %%
compare_orders('ob150211', '2017_08_28')
# Out:
# ** Weight = 1 **
# Skipping Ref Epoch 2016.534
# Skipping Ref Epoch 2016.534
# Epoch: 2015.341
# N_stars =  38  N_par =   3  N_dof =  35  Chi^2 X = 773.6  Chi^2 Y = 156.0  Chi^2 Tot = 929.6
# N_stars =  38  N_par =   6  N_dof =  32  Chi^2 X = 1360.2  Chi^2 Y = 238.8  Chi^2 Tot = 1599.0
# N_stars =  38  N_par =  10  N_dof =  28  Chi^2 X = 996.5  Chi^2 Y = 203.5  Chi^2 Tot = 1199.9
# M = 4: M-1 --> M     Fa = -4.47 pa =  1.0000    Fx = -4.60 px =  1.0000   Fy = -3.70 py =  1.0000
# M = 5: M-1 --> M     Fa =  2.33 pa =  0.0311    Fx =  2.56 px =  0.0608   Fy =  1.21 py =  0.3267
#
# Epoch: 2015.431
# N_stars =  38  N_par =   3  N_dof =  35  Chi^2 X = 375.1  Chi^2 Y = 246.1  Chi^2 Tot = 621.2
# N_stars =  38  N_par =   6  N_dof =  32  Chi^2 X = 581.0  Chi^2 Y = 265.6  Chi^2 Tot = 846.5
# N_stars =  38  N_par =  10  N_dof =  28  Chi^2 X = 1332.1  Chi^2 Y = 306.8  Chi^2 Tot = 1638.9
# M = 4: M-1 --> M     Fa = -2.84 pa =  1.0000    Fx = -3.78 px =  1.0000   Fy = -0.78 py =  1.0000
# ...
